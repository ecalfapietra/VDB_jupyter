# %% [markdown]
# ## Objectifs
# ##### 1 Lire et traiter des données d'entrée avec [PANDAS](https://pandas.pydata.org/)
#
# ##### 2 Représenter la distribution empirique des "fold-change" (**FC**) vs Précision, aka: volcano-plot
#
# ##### 3 Effectuer une analyse de sur-représentation en termes GO
#
#
# ## Ressources : Rappels et illustration de l'analyse de représentation de termes GO
# ###### [TP de MADP](https://github.com/glaunay/tp-proteomics#3-obtention-des-param%C3%A8tres-du-mod%C3%A8le)
# ###### [Fiche Bioconductor](https://www.bioconductor.org/help/course-materials/2015/SeattleApr2015/E_GeneSetEnrichment.html)

# %% [markdown]
# ### Préparation de  l'environnement
#
# ##### Please `pip install -r requirements.txt` first
#
# ##### Directory Configuration
#
# * `workDir` points to the Git project, holds the *tsv* file
# * `libDir` points to Git project subdirectory hosting python library with files names `go.py  stat_utils.py  uniprot.py`
# * `dataDir` points to the data folder with uniprot and GO files

# %%
import sys, os
workDir = f"{os.getcwd()}/.."
libDir = f"{workDir}/lib"
dataDir= f"{workDir}/data" 

sys.path.append(libDir)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Jeux de données
# * Jeux de données de protéomique quantitative au format TSV
# * Ontologie GO au format [owl](http://www.obofoundry.org/ontology/go.html)
# * Entrées Uniprot au format XML
#     * Protéines de l'étude
#     * Protéome d'E.Coli complet
#
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ### Lecture des valeurs experimentales
# Charger ```TCL_wt1.tsv``` dans une [dataframe pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html).
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$
# Retirer les lignes présentant des aberrations numériques
# </span>
# <br/><span style="color:firebrick;font-weight:bold">$\rhd$ Attention aux types des colonnes !</span>

# %%
df = pandas.read_csv("../TCL_wt1.tsv", sep='\t', na_values="#VALEUR!",dtype={
                     'Accession': str,
                     'Corrected Abundance ratio (1.53)': float,
                     'Log2 Corrected Abundance Ratio': float,

                 }).dropna()
df
# Out:
#      Accession                                        Description Gene Symbol  \
# 0       P75936  Basal-body rod modification protein FlgD OS=Es...        flgD
# 1       P76231  Uncharacterized protein YeaC OS=Escherichia co...        yeaC
# 2       P0A8S9  Flagellar transcriptional regulator FlhD OS=Es...        flhD
# 4       P05706  PTS system glucitol/sorbitol-specific EIIA com...        srlB
# 5       P29744  Flagellar hook-associated protein 3 OS=Escheri...        flgL
# ...        ...                                                ...         ...
# 2011    P77330  Prophage lipoprotein Bor homolog OS=Escherichi...        borD
# 2016    P02930  Outer membrane protein TolC OS=Escherichia col...        tolC
# 2020    P0A917  Outer membrane protein X OS=Escherichia coli (...        ompX
# 2021    P02931  Outer membrane protein F OS=Escherichia coli (...        ompF
# 2022    P0AB40  Multiple stress resistance protein BhsA OS=Esc...        bhsA
#
#       Corrected Abundance ratio (1.53)  Log2 Corrected Abundance Ratio  \
# 0                             0.075817                       -3.721335
# 1                             0.092810                       -3.429569
# 2                             0.102614                       -3.284695
# 4                             0.108497                       -3.204277
# 5                             0.124183                       -3.009460
# ...                                ...                             ...
# 2011                          1.535948                        0.619129
# 2016                          1.552288                        0.634396
# 2020                          1.579739                        0.659686
# 2021                          1.754902                        0.811390
# 2022                          1.798039                        0.846424
#
#       Abundance Ratio Adj. P-Value: (127. T3 Tc WT) / (126. T0 WT)  \
# 0                                              0.000055
# 1                                              0.000351
# 2                                              0.000027
# 4                                              0.019963
# 5                                              0.036746
# ...                                                 ...
# 2011                                           0.310725
# 2016                                           0.013373
# 2020                                           0.002226
# 2021                                           0.000068
# 2022                                           0.035928
#
#       LOG10 Adj.P-val
# 0            4.260067
# 1            3.454627
# 2            4.571899
# 4            1.699768
# 5            1.434787
# ...               ...
# 2011         0.507623
# 2016         1.873757
# 2020         2.652391
# 2021         4.164956
# 2022         1.444561
#
# [1746 rows x 7 columns]

# %% [markdown]
# ##### 1. Un premier volcano-plot
#
# Ce type de figure représente pour chaque protéine en abscisse le taux d'abondance et en ordonnée la précision de la mesure.
#
# <span style="color:firebrick;font-weight:bold">$\rhd$ 1. Réaliser un scatter plot matplotlib avec</span>
# <br/><span style="color:firebrick;font-weight:bold">- en x, `Log2 Corrected Abundance Ratio`</span>
# <br/><span style="color:firebrick;font-weight:bold">-  en y, `LOG10 Adj.P-val`</span>
#
# <span style="color:firebrick;font-weight:bold">$\rhd$Vous légenderez les axes, attention `LOG10 Adj.P-val` est en fait `-LOG10 Adj.P-val`, regardez bien.</span>

# %%
fig1, f1_ax = plt.subplots(figsize=(5,3), ncols=1, nrows=1)
f1_ax.scatter(df["Log2 Corrected Abundance Ratio"], df["LOG10 Adj.P-val"])
f1_ax.set_xlabel("Log2 Corrected Abundance Ratio")
f1_ax.set_ylabel("-LOG10 Adj.P-val")
# Out:
# Text(0, 0.5, '-LOG10 Adj.P-val')

# %% [markdown]
# ##### 2. Réaliser des versions évoluées du graphique précédent
# L'objectif est de mettre l'accent sur la région **-Log10 adj Pvalue > 4** et **Log2 corrected abundance ratio > 0**.
# <br/>Pour cela vous revisiterez le scatter plot précedent au travers des versions suivantes:
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ première version : un rectangle de la couleur de votre choix matérialisera la région</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ deuxième version  : une couleur de votre choix représentera les points de la région</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ troisème version (optionnel): Les identifiants uniprot remplaceront les points des protéines de la région</span>

# %%
from matplotlib.patches import Rectangle


fig2, (f2_ax1, f2_ax2, f2_ax3) = plt.subplots(figsize=(10,6), ncols=3, nrows=1)
f2_ax1.scatter(df["Log2 Corrected Abundance Ratio"], df["LOG10 Adj.P-val"])
f2_ax1.set_xlabel("Log2 Corrected Abundance Ratio")
f2_ax1.set_ylabel("-LOG10 Adj.P-val")
f2_ax1.add_patch(Rectangle((0, 4), max(df["Log2 Corrected Abundance Ratio"]), 4, fill=False, edgecolor = 'red'))


df2=df[df['Log2 Corrected Abundance Ratio']>0]
df2=df2[df2['LOG10 Adj.P-val']>4]

f2_ax2.scatter(df['Log2 Corrected Abundance Ratio'],df["LOG10 Adj.P-val"])
f2_ax2.scatter(df2['Log2 Corrected Abundance Ratio'],df2["LOG10 Adj.P-val"],c='red')
f2_ax2.set_xlabel('Log2 Corrected Abundance Ratio')
f2_ax2.set_ylabel('LOG10 Adj.P-val')
# Out:
# Text(0, 0.5, 'LOG10 Adj.P-val')

# %% [markdown]
# #### Analyse ORA
#
# ##### Principes
# Vous disposez d'un objet analyser permettant de réaliser une analyse de la sur-représentation (**ORA**) en termes GO parmi une liste de protéine d'intérêt.
# La fréquence des termes GO dans le protéome totale est utilisée comme référence.
#
# L'objet analyser s'instancie ainsi
# ```python
# from stat_utils import GO_ORA_analyser
# o = GO_ORA_analyser(f"{dataDir}/go.owl", f"{dataDir}/K12_proteome", f"{dataDir}/dataset")
# ```
#
# Il fournit une méthode pour chaque catégorie de termes GO
# <i>{ biological_process, molecular_function, cellular_component }</i>
#
# Une éventuelle surreprésentation des termes GO de la catégorie <i>biological_process</i> est par exemple calculée parmi les protéines P29744 et P05706 de la façon suivante:
#
# ```python
# goTerm_scores = o.biological_process(["P29744", "P05706"])
# ```
# <span style="color:green;font-weight:bold">$\uparrow$ Reproduire cet exemple dans la cellule ci-dessous.$\downarrow$ </span>
# </br><span style="color:firebrick;font-weight:bold"> $\rhd$ Inspecter l'objet retourné par la méthode o.biological_process, que voyez-vous ?</span>

# %%
from stat_utils import GO_ORA_analyser
o = GO_ORA_analyser(f"../data/go.owl", f"../data/K12_proteome", f"../data/dataset")
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation
# Loading ontology
# Loaded
# Reading whole proteome
# 4391 Loaded
# reading experimental protein set
# 2024 Loaded

# %%
goTerm_scores = o.biological_process(["P29744", "P05706"])
goTerm_scores
# Out:
# Building biological process GO Tree
# Extracting biological process ontology
# Applying true path collapsing
# 8 GO terms, 2 leaves, 2 proteins
# Extracting biological process ontology
# Applying true path collapsing
# 2728 GO terms, 6650 leaves, 3128 proteins
# Evaluated 7 / 7 Pathways, based on 2 proteins
# [(0.03359505459608731,
#   'bacterial-type flagellum-dependent cell motility',
#   'GO:0071973',
#   ['P29744']),
#  (0.03485155369421565,
#   'archaeal or bacterial-type flagellum-dependent cell motility',
#   'GO:0097588',
#   ['P29744']),
#  (0.03673476977587685,
#   'phosphoenolpyruvate-dependent sugar phosphotransferase system',
#   'GO:0009401',
#   ['P05706']),
#  (0.037989225453758504, 'cell motility', 'GO:0048870', ['P29744']),
#  (0.04312840804885229, 'localization', 'GO:0051179', ['P29744', 'P05706']),
#  (1.0, 'biological_process', 'GO:0008150', ['P29744', 'P05706'])]

# %% [markdown]
# ###### 2/ Analyser la représentation des termes GO parmi les protéines surabondantes de l'experience
# <span style="color:firebrick;font-weight:bold"> $\rhd$ Vous devrez extraire les identifiants uniprot des protéines aux `Log2 Corrected Abundance Ratio` supérieurs au seuil alpha de 5%.</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ Vous conduirez sur cette liste de protéines une analyse de sur-représentation en termes GO à l'aide d'un objet *GO_ORA_analyser*.</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ Vous pouvez faire varier le seuil d'abondance autour de la valeur alpha.</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ Vous traiterez les 3 catégories *biological_process / molecular_function /cellular_component*.</span>
#
#
#
# Familiarisez-vous avec la structures des dictionnaires de résultas, vous pouvez [les sauvegarder au format json](https://docs.python.org/3/library/json.html).

# %%
prots=list(df[df['Log2 Corrected Abundance Ratio'] > -0.09775202235737335]['Accession'])
prots
# Out:
# ['P39831',
#  'P0AG78',
#  'P0A9H1',
#  'P60955',
#  'P0AB52',
#  'P0AB28',
#  'P77338',
#  'P0AFJ5',
#  'P09833',
#  'P0AEK2',
#  'P33030',
#  'P23173',
#  'P60390',
#  'P0AB98',
#  'P0A7M6',
#  'P0A921',
#  'P0A7M9',
#  'P0A7T3',
#  'P02358',
#  'P0AC69',
#  'P75818',
#  'P0AGI1',
#  'P23894',
#  'P68919',
#  'P0ACG1',
#  'P0A903',
#  'P45799',
#  'P0A7A5',
#  'P0ADE4',
#  'P02943',
#  'P77774',
#  'P0A940',
#  'P0ADN6',
#  'P0A6K3',
#  'P0AEQ1',
#  'P09169',
#  'P05825',
#  'P0ADB7',
#  'P0A915',
#  'P39180',
#  'P0ACF8',
#  'P0A7K2',
#  'P0A7G2',
#  'P0A937',
#  'P0A9L8',
#  'P62399',
#  'P0AER8',
#  'P0A905',
#  'P76471',
#  'P76506',
#  'P13036',
#  'P0A927',
#  'P0AB46',
#  'P10384',
#  'P06971',
#  'P0A910',
#  'P0A908',
#  'P75780',
#  'P06996',
#  'P46474',
#  'P76344',
#  'P06129',
#  'P77330',
#  'P02930',
#  'P0A917',
#  'P02931',
#  'P0AB40']

# %%
go_scores_bio = o.biological_process(prots)
go_scores_mol = o.molecular_function(prots)
go_scores_cel = o.cellular_component(prots)
# Out:
# Evaluated 0 / 7 Pathways, based on 67 proteins
# molecular function process GO Tree
# Extracting molecular function ontology
# Applying true path collapsing
# 181 GO terms, 143 leaves, 49 proteins
# Extracting molecular function ontology
# Applying true path collapsing
# 2264 GO terms, 7807 leaves, 3118 proteins
# Evaluated 180 / 180 Pathways, based on 67 proteins
# cellular component process GO Tree
# Extracting cellular component ontology
# Applying true path collapsing
# 61 GO terms, 128 leaves, 65 proteins
# Extracting cellular component ontology
# Applying true path collapsing
# 239 GO terms, 4698 leaves, 2805 proteins
# Evaluated 60 / 60 Pathways, based on 67 proteins

# %%
go_scores_cel
# Out:
# [(6.89445722883255e-19,
#   'cell outer membrane',
#   'GO:0009279',
#   ['P0A921',
#    'P0ADE4',
#    'P02943',
#    'P0A940',
#    'P09169',
#    'P05825',
#    'P0A915',
#    'P39180',
#    'P0A905',
#    'P76471',
#    'P76506',
#    'P13036',
#    'P0A927',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P0A908',
#    'P75780',
#    'P06996',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P0AB40',
#    'P0A921',
#    'P09169',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P05825',
#    'P0A937',
#    'P06996',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937']),
#  (6.89445722883255e-19,
#   'external encapsulating structure part',
#   'GO:0044462',
#   ['P0A921',
#    'P0ADE4',
#    'P02943',
#    'P0A940',
#    'P09169',
#    'P05825',
#    'P0A915',
#    'P39180',
#    'P0A905',
#    'P76471',
#    'P76506',
#    'P13036',
#    'P0A927',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P0A908',
#    'P75780',
#    'P06996',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P0AB40',
#    'P0A921',
#    'P09169',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P05825',
#    'P0A937',
#    'P06996',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937']),
#  (5.230046427944989e-18,
#   'outer membrane',
#   'GO:0019867',
#   ['P0A910',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P0A940',
#    'P09169',
#    'P05825',
#    'P0A915',
#    'P39180',
#    'P0A905',
#    'P76471',
#    'P76506',
#    'P13036',
#    'P0A927',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P0A908',
#    'P75780',
#    'P06996',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P0AB40',
#    'P0A921',
#    'P09169',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P05825',
#    'P0A937',
#    'P06996',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937']),
#  (6.234406512196581e-18,
#   'external encapsulating structure',
#   'GO:0030312',
#   ['P0A921',
#    'P0ADE4',
#    'P02943',
#    'P0A940',
#    'P09169',
#    'P05825',
#    'P0A915',
#    'P39180',
#    'P0A905',
#    'P76471',
#    'P76506',
#    'P13036',
#    'P0A927',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P0A908',
#    'P75780',
#    'P06996',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P0AB40',
#    'P0A921',
#    'P09169',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P05825',
#    'P0A937',
#    'P06996',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937']),
#  (4.1115666621131435e-14,
#   'cell envelope',
#   'GO:0030313',
#   ['P0AG78',
#    'P0AB46',
#    'P46474',
#    'P76344',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P0A940',
#    'P09169',
#    'P05825',
#    'P0A915',
#    'P39180',
#    'P0A905',
#    'P76471',
#    'P76506',
#    'P13036',
#    'P0A927',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P0A908',
#    'P75780',
#    'P06996',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P0AB40',
#    'P0A921',
#    'P09169',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P05825',
#    'P0A937',
#    'P06996',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937']),
#  (2.337980415596168e-10,
#   'intrinsic component of cell outer membrane',
#   'GO:0031230',
#   ['P0A921',
#    'P09169',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P05825',
#    'P0A937',
#    'P06996',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937']),
#  (3.3770040711206607e-07,
#   'integral component of cell outer membrane',
#   'GO:0045203',
#   ['P0A921', 'P0ADE4', 'P02943', 'P05825', 'P0A937', 'P06996']),
#  (1.258844672944649e-05,
#   'pore complex',
#   'GO:0046930',
#   ['P02943', 'P0A927', 'P0A910', 'P06996', 'P06129', 'P02931']),
#  (1.776565624870157e-05,
#   'Bam protein complex',
#   'GO:1990063',
#   ['P0A903', 'P77774', 'P0A940', 'P0A937']),
#  (7.599336936158556e-05,
#   'membrane protein complex',
#   'GO:0098796',
#   ['P0AB98',
#    'P0AGI1',
#    'P02930',
#    'P02930',
#    'P02931',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P02943',
#    'P0A927',
#    'P0A910',
#    'P06996',
#    'P06129',
#    'P02931']),
#  (0.0001660905441254461,
#   'intrinsic component of periplasmic side of cell outer membrane',
#   'GO:0031246',
#   ['P0A903', 'P77774', 'P0A940', 'P0A937']),
#  (0.00031473405628156437,
#   'protein-containing complex',
#   'GO:0032991',
#   ['P0AB98',
#    'P0AGI1',
#    'P02930',
#    'P02930',
#    'P02931',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P02943',
#    'P0A927',
#    'P0A910',
#    'P06996',
#    'P06129',
#    'P02931',
#    'P0A7K2',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358',
#    'P0ADE4',
#    'P0ACF8']),
#  (0.000400948788036011,
#   'periplasmic side of cell outer membrane',
#   'GO:0031241',
#   ['P0A903', 'P77774', 'P0A940', 'P0A937']),
#  (0.0004944739981457534,
#   'cytosolic ribosome',
#   'GO:0022626',
#   ['P0A7M6', 'P0A7M9', 'P68919', 'P0A7K2', 'P62399', 'P0A7T3', 'P02358']),
#  (0.0004944739981457534,
#   'ribosomal subunit',
#   'GO:0044391',
#   ['P0A7K2',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358']),
#  (0.0007970797255542976,
#   'ribosome',
#   'GO:0005840',
#   ['P0A7K2',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358']),
#  (0.0008722531456043055,
#   'ribonucleoprotein complex',
#   'GO:1990904',
#   ['P0A7K2',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358']),
#  (0.0012895366432163899,
#   'cytosolic large ribosomal subunit',
#   'GO:0022625',
#   ['P0A7M6', 'P0A7M9', 'P68919', 'P0A7K2', 'P62399']),
#  (0.0012895366432163899,
#   'large ribosomal subunit',
#   'GO:0015934',
#   ['P0A7K2', 'P0A7M6', 'P0A7M9', 'P68919', 'P0A7K2', 'P62399']),
#  (0.0015688918031252631,
#   'intracellular organelle part',
#   'GO:0044446',
#   ['P0A7K2',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358']),
#  (0.002459883837502547,
#   'cytosolic part',
#   'GO:0044445',
#   ['P0A7M6', 'P0A7M9', 'P68919', 'P0A7K2', 'P62399', 'P0A7T3', 'P02358']),
#  (0.007552940633146685,
#   'intracellular non-membrane-bounded organelle',
#   'GO:0043232',
#   ['P0A7K2',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358']),
#  (0.007972998443732397,
#   'intracellular organelle',
#   'GO:0043229',
#   ['P0A7K2',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358']),
#  (0.008410171456598444,
#   'organelle part',
#   'GO:0044422',
#   ['P0A7K2',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358']),
#  (0.01576366766735924,
#   'side of membrane',
#   'GO:0098552',
#   ['P60955', 'P0A903', 'P77774', 'P0A940', 'P0A937']),
#  (0.016512905273448723,
#   'cell periphery',
#   'GO:0071944',
#   ['P60955',
#    'P77338',
#    'P09833',
#    'P23173',
#    'P75818',
#    'P0AGI1',
#    'P23894',
#    'P0ADN6',
#    'P0ADB7',
#    'P0AER8',
#    'P77330',
#    'P60955',
#    'P60955',
#    'P23173',
#    'P0AB98',
#    'P0AGI1',
#    'P46474',
#    'P0AGI1',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P0A940',
#    'P09169',
#    'P05825',
#    'P0A915',
#    'P39180',
#    'P0A905',
#    'P76471',
#    'P76506',
#    'P13036',
#    'P0A927',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P0A908',
#    'P75780',
#    'P06996',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P0AB40',
#    'P0A921',
#    'P09169',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P05825',
#    'P0A937',
#    'P06996',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937']),
#  (0.02919365989244726,
#   'organelle',
#   'GO:0043226',
#   ['P0A7K2',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358']),
#  (0.045959007390911646,
#   'membrane',
#   'GO:0016020',
#   ['P0ADB7',
#    'P0ACF8',
#    'P0A937',
#    'P0A910',
#    'P60955',
#    'P60955',
#    'P23173',
#    'P0AB98',
#    'P0AGI1',
#    'P46474',
#    'P0AGI1',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P77338',
#    'P0AB98',
#    'P23894',
#    'P0A940',
#    'P09169',
#    'P0A915',
#    'P39180',
#    'P0AER8',
#    'P13036',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P75780',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P05825',
#    'P0A937',
#    'P06996',
#    'P02930',
#    'P02930',
#    'P02931',
#    'P02943',
#    'P0A927',
#    'P0A910',
#    'P06996',
#    'P06129',
#    'P02931',
#    'P0A921',
#    'P09169',
#    'P0AB98',
#    'P60955',
#    'P77338',
#    'P09833',
#    'P23173',
#    'P75818',
#    'P0AGI1',
#    'P23894',
#    'P0ADN6',
#    'P0ADB7',
#    'P0AER8',
#    'P77330',
#    'P0A910',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P0A940',
#    'P09169',
#    'P05825',
#    'P0A915',
#    'P39180',
#    'P0A905',
#    'P76471',
#    'P76506',
#    'P13036',
#    'P0A927',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P0A908',
#    'P75780',
#    'P06996',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P0AB40']),
#  (0.04613696741514345, 'ion channel complex', 'GO:0034702', ['P02931']),
#  (0.04613696741514345,
#   'TAM protein secretion complex',
#   'GO:0097347',
#   ['P0ADE4']),
#  (0.06460435464929887, 'nucleoid', 'GO:0009295', ['P0ACG1', 'P0ACF8']),
#  (0.06841261160623276, 'efflux pump complex', 'GO:1990281', ['P02930']),
#  (0.06841261160623276, 'MacAB-TolC complex', 'GO:1990196', ['P02930']),
#  (0.09017563636936586,
#   'proton-transporting ATP synthase complex, coupling factor F(o)',
#   'GO:0045263',
#   ['P0AB98']),
#  (0.09017563636936586,
#   'proton-transporting two-sector ATPase complex, proton-transporting domain',
#   'GO:0033177',
#   ['P0AB98']),
#  (0.11427217628913815,
#   'cytosolic small ribosomal subunit',
#   'GO:0022627',
#   ['P0A7T3', 'P02358']),
#  (0.1219994545406534, 'cell surface', 'GO:0009986', ['P0A903', 'P39180']),
#  (0.1504399212237852,
#   'intrinsic component of membrane',
#   'GO:0031224',
#   ['P77338',
#    'P0AB98',
#    'P23894',
#    'P0A940',
#    'P09169',
#    'P0A915',
#    'P39180',
#    'P0AER8',
#    'P13036',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P75780',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P60955',
#    'P23173',
#    'P0AB98',
#    'P0AGI1',
#    'P46474',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P05825',
#    'P0A937',
#    'P06996',
#    'P0AGI1',
#    'P02930',
#    'P02930',
#    'P02931',
#    'P02943',
#    'P0A927',
#    'P0A910',
#    'P06996',
#    'P06129',
#    'P02931',
#    'P0A921',
#    'P09169',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937']),
#  (0.19169927414291865,
#   'proton-transporting two-sector ATPase complex',
#   'GO:0016469',
#   ['P0AB98']),
#  (0.19169927414291865,
#   'proton-transporting ATP synthase complex',
#   'GO:0045259',
#   ['P0AB98']),
#  (0.21583634359830065,
#   'membrane part',
#   'GO:0044425',
#   ['P60955',
#    'P60955',
#    'P23173',
#    'P0AB98',
#    'P0AGI1',
#    'P46474',
#    'P0AGI1',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P77338',
#    'P0AB98',
#    'P23894',
#    'P0A940',
#    'P09169',
#    'P0A915',
#    'P39180',
#    'P0AER8',
#    'P13036',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P75780',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P05825',
#    'P0A937',
#    'P06996',
#    'P02930',
#    'P02930',
#    'P02931',
#    'P02943',
#    'P0A927',
#    'P0A910',
#    'P06996',
#    'P06129',
#    'P02931',
#    'P0A921',
#    'P09169',
#    'P0AB98']),
#  (0.25914993986125623,
#   'integral component of membrane',
#   'GO:0016021',
#   ['P77338',
#    'P0AB98',
#    'P23894',
#    'P0A940',
#    'P09169',
#    'P0A915',
#    'P39180',
#    'P0AER8',
#    'P13036',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P75780',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P60955',
#    'P23173',
#    'P0AB98',
#    'P0AGI1',
#    'P46474',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P05825',
#    'P0A937',
#    'P06996',
#    'P0AGI1',
#    'P02930',
#    'P02930',
#    'P02931',
#    'P02943',
#    'P0A927',
#    'P0A910',
#    'P06996',
#    'P06129',
#    'P02931']),
#  (0.2988814920517699, 'extracellular region', 'GO:0005576', ['P39180']),
#  (0.2995802042396716,
#   'transmembrane transporter complex',
#   'GO:1902495',
#   ['P0AGI1', 'P02930', 'P02930', 'P02931']),
#  (0.4472486812326146,
#   'cytoplasmic side of plasma membrane',
#   'GO:0009898',
#   ['P60955']),
#  (0.4891885456028226,
#   'outer membrane-bounded periplasmic space',
#   'GO:0030288',
#   ['P0AG78', 'P0AB46', 'P46474', 'P76344']),
#  (0.6226080976706289,
#   'periplasmic space',
#   'GO:0042597',
#   ['P39180', 'P0AG78', 'P0AB46', 'P46474', 'P76344']),
#  (0.6489917965179015, 'protein-DNA complex', 'GO:0032993', ['P0ACF8']),
#  (0.7348279157687075,
#   'cell part',
#   'GO:0044464',
#   ['P39831',
#    'P0AB52',
#    'P0AB28',
#    'P0AEK2',
#    'P60390',
#    'P0A7M9',
#    'P02358',
#    'P0AC69',
#    'P68919',
#    'P0ACG1',
#    'P45799',
#    'P0A6K3',
#    'P0ACF8',
#    'P0A7K2',
#    'P0A7G2',
#    'P0A9L8',
#    'P62399',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358',
#    'P0A7K2',
#    'P0A9H1',
#    'P0AFJ5',
#    'P60390',
#    'P0A7A5',
#    'P76344',
#    'P0AB98',
#    'P39180',
#    'P0AG78',
#    'P0AB46',
#    'P46474',
#    'P76344',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P0A940',
#    'P09169',
#    'P05825',
#    'P0A915',
#    'P39180',
#    'P0A905',
#    'P76471',
#    'P76506',
#    'P13036',
#    'P0A927',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P0A908',
#    'P75780',
#    'P06996',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P0AB40',
#    'P0A921',
#    'P09169',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P05825',
#    'P0A937',
#    'P06996',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P60955',
#    'P60955',
#    'P23173',
#    'P0AB98',
#    'P0AGI1',
#    'P46474',
#    'P0AGI1',
#    'P60955',
#    'P77338',
#    'P09833',
#    'P23173',
#    'P75818',
#    'P0AGI1',
#    'P23894',
#    'P0ADN6',
#    'P0ADB7',
#    'P0AER8',
#    'P77330',
#    'P0A903',
#    'P39180']),
#  (0.8030841189335929,
#   'ATP-binding cassette (ABC) transporter complex',
#   'GO:0043190',
#   ['P0AGI1']),
#  (0.8228974485738313,
#   'cytosol',
#   'GO:0005829',
#   ['P39831',
#    'P0AB52',
#    'P0AB28',
#    'P0AEK2',
#    'P60390',
#    'P0A7M9',
#    'P02358',
#    'P0AC69',
#    'P68919',
#    'P0ACG1',
#    'P45799',
#    'P0A6K3',
#    'P0ACF8',
#    'P0A7K2',
#    'P0A7G2',
#    'P0A9L8',
#    'P62399',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358']),
#  (0.8441790061985814,
#   'cytoplasmic part',
#   'GO:0044444',
#   ['P39831',
#    'P0AB52',
#    'P0AB28',
#    'P0AEK2',
#    'P60390',
#    'P0A7M9',
#    'P02358',
#    'P0AC69',
#    'P68919',
#    'P0ACG1',
#    'P45799',
#    'P0A6K3',
#    'P0ACF8',
#    'P0A7K2',
#    'P0A7G2',
#    'P0A9L8',
#    'P62399',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358',
#    'P0A7K2']),
#  (0.8563118939130466,
#   'integral component of plasma membrane',
#   'GO:0005887',
#   ['P60955', 'P23173', 'P0AB98', 'P0AGI1', 'P46474']),
#  (0.8889433826842935,
#   'intrinsic component of plasma membrane',
#   'GO:0031226',
#   ['P60955', 'P23173', 'P0AB98', 'P0AGI1', 'P46474']),
#  (0.9096016974800788,
#   'plasma membrane protein complex',
#   'GO:0098797',
#   ['P0AGI1']),
#  (0.9673783121667554,
#   'plasma membrane part',
#   'GO:0044459',
#   ['P60955', 'P60955', 'P23173', 'P0AB98', 'P0AGI1', 'P46474', 'P0AGI1']),
#  (0.977800174541715,
#   'cytoplasm',
#   'GO:0005737',
#   ['P0A9H1',
#    'P0AFJ5',
#    'P60390',
#    'P0A7A5',
#    'P76344',
#    'P39831',
#    'P0AB52',
#    'P0AB28',
#    'P0AEK2',
#    'P60390',
#    'P0A7M9',
#    'P02358',
#    'P0AC69',
#    'P68919',
#    'P0ACG1',
#    'P45799',
#    'P0A6K3',
#    'P0ACF8',
#    'P0A7K2',
#    'P0A7G2',
#    'P0A9L8',
#    'P62399',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358',
#    'P0A7K2']),
#  (0.9791483518780836,
#   'intracellular part',
#   'GO:0044424',
#   ['P39831',
#    'P0AB52',
#    'P0AB28',
#    'P0AEK2',
#    'P60390',
#    'P0A7M9',
#    'P02358',
#    'P0AC69',
#    'P68919',
#    'P0ACG1',
#    'P45799',
#    'P0A6K3',
#    'P0ACF8',
#    'P0A7K2',
#    'P0A7G2',
#    'P0A9L8',
#    'P62399',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358',
#    'P0A7K2',
#    'P0A9H1',
#    'P0AFJ5',
#    'P60390',
#    'P0A7A5',
#    'P76344',
#    'P0AB98']),
#  (0.9999695834495801,
#   'plasma membrane',
#   'GO:0005886',
#   ['P60955',
#    'P77338',
#    'P09833',
#    'P23173',
#    'P75818',
#    'P0AGI1',
#    'P23894',
#    'P0ADN6',
#    'P0ADB7',
#    'P0AER8',
#    'P77330',
#    'P60955',
#    'P60955',
#    'P23173',
#    'P0AB98',
#    'P0AGI1',
#    'P46474',
#    'P0AGI1']),
#  (1.0,
#   'cellular_component',
#   'GO:0005575',
#   ['P39831',
#    'P0AB52',
#    'P0AB28',
#    'P0AEK2',
#    'P60390',
#    'P0A7M9',
#    'P02358',
#    'P0AC69',
#    'P68919',
#    'P0ACG1',
#    'P45799',
#    'P0A6K3',
#    'P0ACF8',
#    'P0A7K2',
#    'P0A7G2',
#    'P0A9L8',
#    'P62399',
#    'P0A7M6',
#    'P0A7M9',
#    'P68919',
#    'P0A7K2',
#    'P62399',
#    'P0A7T3',
#    'P02358',
#    'P0A7K2',
#    'P0A9H1',
#    'P0AFJ5',
#    'P60390',
#    'P0A7A5',
#    'P76344',
#    'P0AB98',
#    'P39180',
#    'P0AG78',
#    'P0AB46',
#    'P46474',
#    'P76344',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P0A940',
#    'P09169',
#    'P05825',
#    'P0A915',
#    'P39180',
#    'P0A905',
#    'P76471',
#    'P76506',
#    'P13036',
#    'P0A927',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P0A908',
#    'P75780',
#    'P06996',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P0AB40',
#    'P0A921',
#    'P09169',
#    'P0A921',
#    'P0ADE4',
#    'P02943',
#    'P05825',
#    'P0A937',
#    'P06996',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P60955',
#    'P60955',
#    'P23173',
#    'P0AB98',
#    'P0AGI1',
#    'P46474',
#    'P0AGI1',
#    'P60955',
#    'P77338',
#    'P09833',
#    'P23173',
#    'P75818',
#    'P0AGI1',
#    'P23894',
#    'P0ADN6',
#    'P0ADB7',
#    'P0AER8',
#    'P77330',
#    'P0A903',
#    'P39180',
#    'P77338',
#    'P0AB98',
#    'P23894',
#    'P0A940',
#    'P09169',
#    'P0A915',
#    'P39180',
#    'P0AER8',
#    'P13036',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P75780',
#    'P06129',
#    'P02930',
#    'P0A917',
#    'P02931',
#    'P02930',
#    'P02930',
#    'P02931',
#    'P02943',
#    'P0A927',
#    'P0A910',
#    'P06996',
#    'P06129',
#    'P02931',
#    'P0ADB7',
#    'P0ACF8',
#    'P0A937',
#    'P0A910',
#    'P0A910',
#    'P0ADE4',
#    'P0ACF8',
#    'P0ACG1',
#    'P0ACF8',
#    'P39180'])]

# %% [markdown]
# ## Une première application: représentation riche du résultat de l'analyse
#
#
# ### Mise en forme "riche" des résultats grâce au notebook
#
# Jupyter permet d'étendre le concept de la méthode **__str__()** afin de produire du contenu HTML.
#  Ainsi, tout objet impémentant une méthode **_repr_html_()** sera affiché, via son rendu HTML, dans la cellule d'un notebook.
#
# ```python
# class Point():
#     def __init__(self, x, y, z):
#         self.x = x
#         self.y = y
#         self.z = z
#     def _repr_html_(self):
#         htmlString = "<table><thead><tr><td>Abscisse</td><td>Ordonnée</td><td>Cote</td></tr></thead>"
#         htmlString += f"<tbody><tr><td>{self.x}</td><td>{self.y}</td><td>{self.z}</td></tr></tbody></table>"
#         return htmlString
# Point(2,3,4)
# ```
# Affichera
#
# ![caption](../figs/reprhtml.png)
#
#
# ### Intégration des résultats à la visualisation du notebook
#
# En vous inspirant de la fonction ci-dessus, implémenter une classe Rich_GO_ORA dont la méthode [`_repr_html_`](https://ipython.readthedocs.io/en/stable/config/integrating.html) permettra un affichage plus lisible d'une des analyses `biological_process / molecular_function /cellular_component`
#
# Un exemple possible est,
# ![caption](../figs/_repr_html_.png)
#
# (Bonus): clicker sur le nom du terme GO envoie vers sa description.
# Pour cela, afficher le nom du pathway dans une balise hyperlien pour permettre d'acceder à la page de description du terme GO.
#
# Les termes GO sont accessibles aux URL de la forme
# `http://amigo.geneontology.org/amigo/term/GO:GO_NUMBER`.

# %%
class Rich_GO_ORA():
    def __init__(self, x):
        self.x = x
    def _repr_html_(self):
        htmlString = "<table><thead><tr><td>p_value</td><td>Pathway name</td><td>GO</td><td>nAccession</td></tr></thead>"
        for l in self.x:
            htmlString += f"""<tbody><tr><td>{l[0]}</td><td>{l[1]}</td><td><a href="http://amigo.geneontology.org/amigo/term/{l[2]}">{l[2]}</a><td>{len(l[3])}</td></tr></tbody>"""
        htmlString += "</table>"
        return htmlString
Rich_GO_ORA(go_scores_cel)
# Out:
# <table><thead><tr><td>p_value</td><td>Pathway name</td><td>GO</td><td>nAccession</td></tr></thead><tbody><tr><td>6.89445722883255e-19</td><td>cell outer membrane</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0009279">GO:0009279</a><td>36</td></tr></tbody><tbody><tr><td>6.89445722883255e-19</td><td>external encapsulating structure part</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0044462">GO:0044462</a><td>36</td></tr></tbody><tbody><tr><td>5.230046427944989e-18</td><td>outer membrane</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0019867">GO:0019867</a><td>37</td></tr></tbody><tbody><tr><td>6.234406512196581e-18</td><td>external encapsulating structure</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0030312">GO:0030312</a><td>36</td></tr></tbody><tbody><tr><td>4.1115666621131435e-14</td><td>cell envelope</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0030313">GO:0030313</a><td>40</td></tr></tbody><tbody><tr><td>2.337980415596168e-10</td><td>intrinsic component of cell outer membrane</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0031230">GO:0031230</a><td>12</td></tr></tbody><tbody><tr><td>3.3770040711206607e-07</td><td>integral component of cell outer membrane</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0045203">GO:0045203</a><td>6</td></tr></tbody><tbody><tr><td>1.258844672944649e-05</td><td>pore complex</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0046930">GO:0046930</a><td>6</td></tr></tbody><tbody><tr><td>1.776565624870157e-05</td><td>Bam protein complex</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:1990063">GO:1990063</a><td>4</td></tr></tbody><tbody><tr><td>7.599336936158556e-05</td><td>membrane protein complex</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0098796">GO:0098796</a><td>15</td></tr></tbody><tbody><tr><td>0.0001660905441254461</td><td>intrinsic component of periplasmic side of cell outer membrane</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0031246">GO:0031246</a><td>4</td></tr></tbody><tbody><tr><td>0.00031473405628156437</td><td>protein-containing complex</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0032991">GO:0032991</a><td>25</td></tr></tbody><tbody><tr><td>0.000400948788036011</td><td>periplasmic side of cell outer membrane</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0031241">GO:0031241</a><td>4</td></tr></tbody><tbody><tr><td>0.0004944739981457534</td><td>cytosolic ribosome</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0022626">GO:0022626</a><td>7</td></tr></tbody><tbody><tr><td>0.0004944739981457534</td><td>ribosomal subunit</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0044391">GO:0044391</a><td>8</td></tr></tbody><tbody><tr><td>0.0007970797255542976</td><td>ribosome</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0005840">GO:0005840</a><td>8</td></tr></tbody><tbody><tr><td>0.0008722531456043055</td><td>ribonucleoprotein complex</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:1990904">GO:1990904</a><td>8</td></tr></tbody><tbody><tr><td>0.0012895366432163899</td><td>cytosolic large ribosomal subunit</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0022625">GO:0022625</a><td>5</td></tr></tbody><tbody><tr><td>0.0012895366432163899</td><td>large ribosomal subunit</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0015934">GO:0015934</a><td>6</td></tr></tbody><tbody><tr><td>0.0015688918031252631</td><td>intracellular organelle part</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0044446">GO:0044446</a><td>8</td></tr></tbody><tbody><tr><td>0.002459883837502547</td><td>cytosolic part</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0044445">GO:0044445</a><td>7</td></tr></tbody><tbody><tr><td>0.007552940633146685</td><td>intracellular non-membrane-bounded organelle</td><td><a href="http://amigo.geneontology.org/ ...

# %% [markdown]
# ## Une deuxième application: volcano plot améliorés
# ###### PANDAS
# En choisissant comme seuil la valeur `alpha` du TP précédent, veuillez extraires les identifiants uniprot des protéines sur-abondantes (rappel les valeurs d'abondance sont celles de la colonne `Log2 Corrected Abundance Ratio`).
#
# Vous devrez avoir dans des listes distinctes:
# * identifiants uniprot
# * `Log2 Corrected Abundance Ratio`
# * `LOG10 Adj.P-val'`
#
# ###### Représentation graphiques
# * Pour la catégorie de termes GO (biological_process / molecular_function /cellular_component) de votre choix
#     * Générer une grille de 4 graphiques
#     * Dans chaque graphique colorez dans une couleur différentes les protéines porteuses de 4 termes de GO que vous estimez les plus pertinents
#     * Donnez le nom de la catégorie générale à la grille
#     * Donnez le nom du terme GO représenté dans chaque graphique avec une couleur de titre cohérente.

# %%
df_alpha=df[df['Log2 Corrected Abundance Ratio'] > -0.09775202235737335]


identifiants_uniprot = list(df["Accession"])
Log2_Corrected_Abundance_Ratio = list(df["Log2 Corrected Abundance Ratio"])
LOG10_Adj_P_value = list(df["LOG10 Adj.P-val"])
df_alpha
# Out:
#      Accession                                        Description Gene Symbol  \
# 1902    P39831  NADP-dependent 3-hydroxy acid dehydrogenase Yd...        ydfG
# 1904    P0AG78  Sulfate-binding protein OS=Escherichia coli (s...         sbp
# 1905    P0A9H1  G/U mismatch-specific DNA glycosylase OS=Esche...         mug
# 1906    P60955  Prolipoprotein diacylglyceryl transferase OS=E...         lgt
# 1910    P0AB52  Protein YchN OS=Escherichia coli (strain K12) ...        ychN
# ...        ...                                                ...         ...
# 2011    P77330  Prophage lipoprotein Bor homolog OS=Escherichi...        borD
# 2016    P02930  Outer membrane protein TolC OS=Escherichia col...        tolC
# 2020    P0A917  Outer membrane protein X OS=Escherichia coli (...        ompX
# 2021    P02931  Outer membrane protein F OS=Escherichia coli (...        ompF
# 2022    P0AB40  Multiple stress resistance protein BhsA OS=Esc...        bhsA
#
#       Corrected Abundance ratio (1.53)  Log2 Corrected Abundance Ratio  \
# 1902                          0.937908                       -0.092481
# 1904                          0.939869                       -0.089468
# 1905                          0.942484                       -0.085460
# 1906                          0.943791                       -0.083461
# 1910                          0.949673                       -0.074497
# ...                                ...                             ...
# 2011                          1.535948                        0.619129
# 2016                          1.552288                        0.634396
# 2020                          1.579739                        0.659686
# 2021                          1.754902                        0.811390
# 2022                          1.798039                        0.846424
#
#       Abundance Ratio Adj. P-Value: (127. T3 Tc WT) / (126. T0 WT)  \
# 1902                                           1.000000
# 1904                                           1.000000
# 1905                                           1.000000
# 1906                                           1.000000
# 1910                                           1.000000
# ...                                                 ...
# 2011                                           0.310725
# 2016                                           0.013373
# 2020                                           0.002226
# 2021                                           0.000068
# 2022                                           0.035928
#
#       LOG10 Adj.P-val
# 1902         0.000000
# 1904         0.000000
# 1905         0.000000
# 1906         0.000000
# 1910         0.000000
# ...               ...
# 2011         0.507623
# 2016         1.873757
# 2020         2.652391
# 2021         4.164956
# 2022         1.444561
#
# [67 rows x 7 columns]

# %%
fig3, ((f3_ax1, f3_ax2), (f3_ax3, f3_ax4) ) = plt.subplots(figsize=(15,15), ncols=2, nrows=2)
fig3.suptitle('Molecular function')

go1 = go_scores_mol[0][3]
ax1_points=df_alpha[df_alpha['Accession'].isin(go1)]
f3_ax1.scatter(df['Log2 Corrected Abundance Ratio'],df["LOG10 Adj.P-val"], c='grey')
f3_ax1.scatter(df_alpha['Log2 Corrected Abundance Ratio'],df_alpha["LOG10 Adj.P-val"], c='black')
f3_ax1.scatter(ax1_points["Log2 Corrected Abundance Ratio"], ax1_points["LOG10 Adj.P-val"],c='red')
f3_ax1.set_title(label="Porin activity", c='red')
f3_ax1.set_xlabel('Log2 Corrected Abundance Ratio')
f3_ax1.set_ylabel('LOG10 Adj.P-val')

go2 = go_scores_mol[1][3]
ax2_points=df_alpha[df_alpha['Accession'].isin(go2)]
f3_ax2.scatter(df['Log2 Corrected Abundance Ratio'],df["LOG10 Adj.P-val"], c='grey')
f3_ax2.scatter(df_alpha['Log2 Corrected Abundance Ratio'],df_alpha["LOG10 Adj.P-val"], c='black')
f3_ax2.scatter(ax2_points["Log2 Corrected Abundance Ratio"], ax2_points["LOG10 Adj.P-val"],c='blue')
f3_ax2.set_title(label="Channel activity", c='blue')
f3_ax2.set_xlabel('Log2 Corrected Abundance Ratio')
f3_ax2.set_ylabel('LOG10 Adj.P-val')

go3 = go_scores_mol[2][3]
ax3_points=df_alpha[df_alpha['Accession'].isin(go3)]
f3_ax3.scatter(df['Log2 Corrected Abundance Ratio'],df["LOG10 Adj.P-val"], c='grey')
f3_ax3.scatter(df_alpha['Log2 Corrected Abundance Ratio'],df_alpha["LOG10 Adj.P-val"], c='black')
f3_ax3.scatter(ax3_points["Log2 Corrected Abundance Ratio"], ax3_points["LOG10 Adj.P-val"],c='green')
f3_ax3.set_title(label="Structural molecule activity", c='green')
f3_ax3.set_xlabel('Log2 Corrected Abundance Ratio')
f3_ax3.set_ylabel('LOG10 Adj.P-val')

go4 = go_scores_mol[3][3]
ax4_points=df_alpha[df_alpha['Accession'].isin(go4)]
f3_ax4.scatter(df['Log2 Corrected Abundance Ratio'],df["LOG10 Adj.P-val"], c='grey')
f3_ax4.scatter(df_alpha['Log2 Corrected Abundance Ratio'],df_alpha["LOG10 Adj.P-val"], c='black')
f3_ax4.scatter(ax4_points["Log2 Corrected Abundance Ratio"], ax4_points["LOG10 Adj.P-val"],c='orange')
f3_ax4.set_title(label="Structural constituent of ribosome", c='orange')
f3_ax4.set_xlabel('Log2 Corrected Abundance Ratio')
f3_ax4.set_ylabel('LOG10 Adj.P-val')

fig3.legend(["all proteins", "over-abundant proteins"], loc =(0.42,0.4375))
